# %% [markdown]
# # Simple RNN (Recurrent Neural Network)

# %%
import numpy as np
from keras.callbacks import (
    CSVLogger,
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)
from keras.layers import SimpleRNN, Dense, Input
from keras.losses import MeanSquaredError
from keras.metrics import MeanSquaredError as MSEMetric
from keras.models import Sequential
from keras.optimizers import Adam

# %%
# The Fibonacci Sequence
def fibonacci(n):
    """Generate Fibonacci sequence up to n terms."""
    fib_list = [0, 1]
    for i in range(2, n):
        fib_list.append(fib_list[-1] + fib_list[-2])
    return fib_list[:n]


raw_seq = fibonacci(15)
n_steps = 5  # Use 5 previous numbers to predict the next
n_features = 1


# Function to convert a sequence into (X, y) samples
def create_sequences(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


X, y = create_sequences(raw_seq, n_steps)

# Reshape input to be [samples, timesteps, features] for LSTM
X = X.reshape((X.shape[0], X.shape[1], n_features))

print(f"Sample X (Input): {X[0].flatten()} -> y (Output): {y[0]}")
print(f"Sample X (Input): {X[-1].flatten()} -> y (Output): {y[-1]}")
# Out:
# Sample X (Input): [0 1 1 2 3] -> y (Output): 5
# Sample X (Input): [ 34  55  89 144 233] -> y (Output): 377

# %%
simple_rnn = Sequential(
    layers=[
        Input(shape=(n_steps, n_features)),
        SimpleRNN(64),
        Dense(64),
        Dense(32),
        Dense(1),
    ],
    name="simple_rnn",
)

# %%
simple_rnn.layers
# Out:
# [<SimpleRNN name=simple_rnn, built=True>,
#  <Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %%
simple_rnn.summary()
# Out:
# Model: "simple_rnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,497 (41.00 KB)
#  Trainable params: 10,497 (41.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
simple_rnn.compile(optimizer=Adam(), loss=MeanSquaredError(), metrics=[MSEMetric()])  # type: ignore

# %%
early_stopping_callback = EarlyStopping(
    monitor="loss", patience=10, restore_best_weights=True
)
model_checkpoint_callback = ModelCheckpoint(
    filepath="../../Models/simple_rnn.keras",
    monitor="loss",
    save_best_only=True,
    mode="min",
)
tensorboard_callback = TensorBoard(
    log_dir="../../Logs/simple_rnn_logs",
    histogram_freq=1,
    write_images=True,
    write_steps_per_second=True,
)
# tensorboard --logdir="Logs/simple_rnn_logs"

csvlogger_callback = CSVLogger("../../Logs/simple_rnn_logs.csv")

reduce_lr_callback = ReduceLROnPlateau(monitor="loss", factor=0.5, patience=5)

simple_rnn_history = simple_rnn.fit(
    X,
    y,
    epochs=200,
    callbacks=[
        early_stopping_callback,
        model_checkpoint_callback,
        tensorboard_callback,
        csvlogger_callback,
        reduce_lr_callback,
    ],
)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 22916.2031 - mean_squared_error: 22916.2031 - learning_rate: 0.0010
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 22712.3711 - mean_squared_error: 22712.3711 - learning_rate: 0.0010
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 22510.8340 - mean_squared_error: 22510.8340 - learning_rate: 0.0010
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 22310.8496 - mean_squared_error: 22310.8496 - learning_rate: 0.0010
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - loss: 22111.7324 - mean_squared_error: 22111.7324 - learning_rate: 0.0010
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 21912.7344 - mean_squared_error: 21912.7344 - learning_rate: 0.0010
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 21713.0547 - mean_squared_error: 21713.0547 - learning_rate: 0.0010
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 21511.9316 - mean_squared_error: 21511.9316 - learning_rate: 0.0010
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - loss: 21308.6523 - mean_squared_error: 21308.6523 - learning_rate: 0.0010
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 21102.5664 - mean_squared_error: 21102.5664 - learning_rate: 0.0010
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 20893.0977 - mean_squared_error: 20893.0977 - learning_rate: 0.0010
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 20679.7207 - mean_squared_error: 20679.7207 - learning_rate: 0.0010
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 20461.9785 - mean_squared_error: 20461.9785 - learning_rate: 0.0010
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 20239.4492 - mean_squared_error: 20239.4492 - learning_rate: 0.0010
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 20011.7539 - mean_squared_error: 20011.7539 - learning_rate: 0.0010
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 19778.5430 - mean_squared_error: 19778.5430 - learning_rate: 0.0010
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 19539.4961 - mean_squared_error: 19539.4961 - learning_rate: 0.0010
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 19294.3203 - mean_squared_error: 19294.3203 - learning_rate: 0.0010
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 19042.7441 - mean_squared_error: 19042.7441 - learning_rate: 0.0010
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 18784.5195 - mean_squared_error: 18784.5195 - learning_rate: 0.0010
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 18519.4316 - mean_squared_error: 18519.4316 - learning_rate: 0.0010
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 18247.2832 - mean_squared_error: 18247.2832 - learning_rate: 0.0010
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 17967.9238 - mean_squared_error: 17967.9238 - learning_rate: 0.0010
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 17681.2383 - mean_squared_error: 17681.2383 - learning_rate: 0.0010
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 17387.1562 - mean_squared_error: 17387.1562 - learning_rate: 0.0010
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 17085.6504 - mean_squared_error: 17085.6504 - learning_rate: 0.0010
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 16776.7598 - mean_squared_error: 16776.7598 - learning_rate: 0.0010
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 16460.5742 - mean_squared_error: 16460.5742 - learning_rate: 0.0010
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 16137.2627 - mean_squared_error: 16137.2627 - learning_rate: 0.0010
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 15807.0391 - mean_squared_error: 15807.0391 - learning_rate: 0.0010
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 15470.1797 - mean_squared_error: 15470.1797 - learning_rate: 0.0010
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 15127.1123 - mean_squared_error: 15127.1123 - learning_rate: 0.0010
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 14778.5684 - mean_squared_error: 14778.5684 - learning_rate: 0.0010
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 14425.2480 - mean_squared_error: 14425.2480 - learning_rate: 0.0010
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 14067.3730 - mean_squared_error: 14067.3730 - learning_rate: 0.0010
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 13704.8848 - mean_squared_error: 13704.8848 - learning_rate: 0.0010
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 13337.8486 - mean_squared_error: 13337.8486 - learning_rate: 0.0010
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 12966.5918 - mean_squared_error: 12966.5918 - learning_rate: 0.0010
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 12591.6631 - mean_squared_error: 12591.6631 - learning_rate: 0.0010
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 12213.7891 - mean_squared_error: 12213.7891 - learning_rate: 0.0010
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 11833.8418 - mean_squared_error: 11833.8418 - learning_rate: 0.0010
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 11452.8105 - mean_squared_error: 11452.8105 - learning_rate: 0.0010
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 11071.7207 - mean_squared_error: 11071.7207 - learning_rate: 0.0010
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 10691.5215 - mean_squared_error: 10691.5215 - learning_rate: 0.0010
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 10312.9111 - mean_squared_error: 10312.9111 - learning_rate: 0.0010
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 9936.2129 - mean_squared_error: 9936.2129 - learning_rate: 0.0010
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 9561.3691 - mean_squared_error: 9561.3691 - learning_rate: 0.0010
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 9188.1406 - mean_squared_error: 9188.1406 - learning_rate: 0.0010
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 8816.4160 - mean_squared_error: 8816.4160 - learning_rate: 0.0010
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 8446.4746 - mean_squared_error: 8446.4746 - learning_rate: 0.0010
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 8079.0107 - mean_squared_error: 8079.0107 - learning_rate: 0.0010
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 7715.0537 - mean_squared_error: 7715.0537 - learning_rate: 0.0010
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 7355.7764 - mean_squared_error: 7355.7764 - learning_rate: 0.0010
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 7002.2773 - mean_squared_error: 7002.2773 - learning_rate: 0.0010
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - loss: 6655.3462 - mean_squared_error: 6655.3462 - learning_rate: 0.0010
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - loss: 6315.5493 - mean_squared_error: 6315.5493 - learning_rate: 0.0010
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 5983.4619 - mean_squared_error: 5983.4619 - learning_rate: 0.0010
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 5659.0786 - mean_squared_error: 5659.0786 - learning_rate: 0.0010
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 5341.7568 - mean_squared_error: 5341.7568 - learning_rate: 0.0010
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 5031.5835 - mean_squared_error: 5031.5835 - learning_rate: 0.0010
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - loss: 4729.1709 - mean_squared_error: 4729.1709 - learning_rate: 0.0010
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 4435.1768 - mean_squared_error: 4435.1768 - learning_rate: 0.0010
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 4150.0308 - mean_squared_error: 4150.0308 - learning_rate: 0.0010
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 3874.2075 - mean_squared_error: 3874.2075 - learning_rate: 0.0010
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 3608.7800 - mean_squared_error: 3608.7800 - learning_rate: 0.0010
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 3354.9792 - mean_squared_error: 3354.9792 - learning_rate: 0.0010
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 3113.3979 - mean_squared_error: 3113.3979 - learning_rate: 0.0010
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 2883.9773 - mean_squared_error: 2883.9773 - learning_rate: 0.0010
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 2666.3276 - mean_squared_error: 2666.3276 - learning_rate: 0.0010
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 2459.9707 - mean_squared_error: 2459.9707 - learning_rate: 0.0010
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 2264.5083 - mean_squared_error: 2264.5083 - learning_rate: 0.0010
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 2079.6821 - mean_squared_error: 2079.6821 - learning_rate: 0.0010
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1905.3256 - mean_squared_error: 1905.3256 - learning_rate: 0.0010
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1741.4596 - mean_squared_error: 1741.4596 - learning_rate: 0.0010
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1588.1844 - mean_squared_error: 1588.1844 - learning_rate: 0.0010
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1445.1581 - mean_squared_error: 1445.1581 - learning_rate: 0.0010
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1311.7659 - mean_squared_error: 1311.7659 - learning_rate: 0.0010
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1187.6290 - mean_squared_error: 1187.6290 - learning_rate: 0.0010
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1071.9062 - mean_squared_error: 1071.9062 - learning_rate: 0.0010
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 963.0016 - mean_squared_error: 963.0016 - learning_rate: 0.0010
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 860.2231 - mean_squared_error: 860.2231 - learning_rate: 0.0010
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 764.3633 - mean_squared_error: 764.3633 - learning_rate: 0.0010
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 675.8587 - mean_squared_error: 675.8587 - learning_rate: 0.0010
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 593.8246 - mean_squared_error: 593.8246 - learning_rate: 0.0010
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 517.8713 - mean_squared_error: 517.8713 - learning_rate: 0.0010
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 448.7651 - mean_squared_error: 448.7651 - learning_rate: 0.0010
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 386.0811 - mean_squared_error: 386.0811 - learning_rate: 0.0010
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - loss: 328.6082 - mean_squared_error: 328.6082 - learning_rate: 0.0010
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 276.8545 - mean_squared_error: 276.8545 - learning_rate: 0.0010
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 231.2174 - mean_squared_error: 231.2174 - learning_rate: 0.0010
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 190.6255 - mean_squared_error: 190.6255 - learning_rate: 0.0010
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 154.6890 - mean_squared_error: 154.6890 - learning_rate: 0.0010
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 123.7621 - mean_squared_error: 123.7621 - learning_rate: 0.0010
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 97.3841 - mean_squared_error: 97.3841 - learning_rate: 0.0010
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 74.8812 - mean_squared_error: 74.8812 - learning_rate: 0.0010
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 56.1714 - mean_squared_error: 56.1714 - learning_rate: 0.0010
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 41.0347 - mean_squared_error: 41.0347 - learning_rate: 0.0010
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 28.8620 - mean_squared_error: 28.8620 - learning_rate: 0.0010
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 19.3773 - mean_squared_error: 19.3773 - learning_rate: 0.0010
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 12.5171 - mean_squared_error: 12.5171 - learning_rate: 0.0010
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 7.8099 - mean_squared_error: 7.8099 - learning_rate: 0.0010
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 4.6441 - mean_squared_error: 4.6441 - learning_rate: 0.0010
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 2.6858 - mean_squared_error: 2.6858 - learning_rate: 0.0010
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.6468 - mean_squared_error: 1.6468 - learning_rate: 0.0010
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.1916 - mean_squared_error: 1.1916 - learning_rate: 0.0010
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.2486 - mean_squared_error: 1.2486 - learning_rate: 0.0010
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.9118 - mean_squared_error: 1.9118 - learning_rate: 0.0010
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 3.0746 - mean_squared_error: 3.0746 - learning_rate: 0.0010
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 4.4686 - mean_squared_error: 4.4686 - learning_rate: 0.0010
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 5.8580 - mean_squared_error: 5.8580 - learning_rate: 0.0010
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.0473 - mean_squared_error: 7.0473 - learning_rate: 5.0000e-04
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.4570 - mean_squared_error: 7.4570 - learning_rate: 5.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.6702 - mean_squared_error: 7.6702 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.7242 - mean_squared_error: 7.7242 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 7.6543 - mean_squared_error: 7.6543 - learning_rate: 5.0000e-04

# %%
# New input data (the last n_steps numbers)
x_input = np.array([55, 89, 144, 233, 377])

# Reshape the input for the model: (1 sample, n_steps timesteps, 1 feature)
x_input = x_input.reshape((1, n_steps, n_features))

# Make the prediction
yhat = simple_rnn.predict(x_input)

print(f"\n--- Prediction Result ---")
print(f"Input Sequence: {x_input.flatten()}")
# Round the prediction as Fibonacci numbers are integers
print(f"Predicted Next Number: {round(yhat[0][0])}")
print(f"Expected Next Number: ", x_input.flatten()[-1] + x_input.flatten()[-2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#
# --- Prediction Result ---
# Input Sequence: [ 55  89 144 233 377]
# Predicted Next Number: 381
# Expected Next Number:  610
