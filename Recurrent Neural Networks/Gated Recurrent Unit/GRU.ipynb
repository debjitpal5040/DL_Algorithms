# %% [markdown]
# # GRU (Gated Recurrent Unit)

# %%
import numpy as np
from keras.callbacks import (
    CSVLogger,
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)
from keras.layers import GRU, Dense, Input
from keras.losses import MeanSquaredError
from keras.metrics import MeanSquaredError as MSEMetric
from keras.models import Sequential
from keras.optimizers import Adam

# %%
# The Fibonacci Sequence
def fibonacci(n):
    """Generate Fibonacci sequence up to n terms."""
    fib_list = [0, 1]
    for i in range(2, n):
        fib_list.append(fib_list[-1] + fib_list[-2])
    return fib_list[:n]


raw_seq = fibonacci(15)
n_steps = 5  # Use 5 previous numbers to predict the next
n_features = 1


# Function to convert a sequence into (X, y) samples
def create_sequences(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


X, y = create_sequences(raw_seq, n_steps)

# Reshape input to be [samples, timesteps, features] for LSTM
X = X.reshape((X.shape[0], X.shape[1], n_features))

print(f"Sample X (Input): {X[0].flatten()} -> y (Output): {y[0]}")
print(f"Sample X (Input): {X[-1].flatten()} -> y (Output): {y[-1]}")
# Out:
# Sample X (Input): [0 1 1 2 3] -> y (Output): 5
# Sample X (Input): [ 34  55  89 144 233] -> y (Output): 377

# %%
gru = Sequential(
    layers=[
        Input(shape=(n_steps, n_features)),
        GRU(64),
        Dense(64),
        Dense(32),
        Dense(1),
    ],
    name="gru",
)

# %%
gru.layers
# Out:
# [<GRU name=gru, built=True>,
#  <Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %%
gru.summary()
# Out:
# Model: "gru"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,137 (74.75 KB)
#  Trainable params: 19,137 (74.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
gru.compile(optimizer=Adam(), loss=MeanSquaredError(), metrics=[MSEMetric()])  # type: ignore

# %%
early_stopping_callback = EarlyStopping(
    monitor="loss", patience=10, restore_best_weights=True
)
model_checkpoint_callback = ModelCheckpoint(
    filepath="../../Models/gru.keras",
    monitor="loss",
    save_best_only=True,
    mode="min",
)
tensorboard_callback = TensorBoard(
    log_dir="../../Logs/gru_logs",
    histogram_freq=1,
    write_images=True,
    write_steps_per_second=True,
)
# tensorboard --logdir="Logs/gru_logs"

csvlogger_callback = CSVLogger("../../Logs/gru_logs.csv")

reduce_lr_callback = ReduceLROnPlateau(monitor="loss", factor=0.5, patience=5)

gru_history = gru.fit(
    X,
    y,
    epochs=200,
    callbacks=[
        early_stopping_callback,
        model_checkpoint_callback,
        tensorboard_callback,
        csvlogger_callback,
        reduce_lr_callback,
    ],
)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 22828.8262 - mean_squared_error: 22828.8262 - learning_rate: 0.0010
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - loss: 22686.0820 - mean_squared_error: 22686.0820 - learning_rate: 0.0010
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step - loss: 22544.2910 - mean_squared_error: 22544.2910 - learning_rate: 0.0010
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 22402.5449 - mean_squared_error: 22402.5449 - learning_rate: 0.0010
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 22260.2617 - mean_squared_error: 22260.2617 - learning_rate: 0.0010
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 22116.9102 - mean_squared_error: 22116.9102 - learning_rate: 0.0010
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 21971.9414 - mean_squared_error: 21971.9414 - learning_rate: 0.0010
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 21824.8398 - mean_squared_error: 21824.8398 - learning_rate: 0.0010
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 21675.1094 - mean_squared_error: 21675.1094 - learning_rate: 0.0010
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 21522.3008 - mean_squared_error: 21522.3008 - learning_rate: 0.0010
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 21365.9746 - mean_squared_error: 21365.9746 - learning_rate: 0.0010
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 21205.7363 - mean_squared_error: 21205.7363 - learning_rate: 0.0010
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 21041.1992 - mean_squared_error: 21041.1992 - learning_rate: 0.0010
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 20872.0098 - mean_squared_error: 20872.0098 - learning_rate: 0.0010
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step - loss: 20697.8516 - mean_squared_error: 20697.8516 - learning_rate: 0.0010
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - loss: 20518.4375 - mean_squared_error: 20518.4375 - learning_rate: 0.0010
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 20333.5137 - mean_squared_error: 20333.5137 - learning_rate: 0.0010
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 20142.8457 - mean_squared_error: 20142.8457 - learning_rate: 0.0010
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 19946.2227 - mean_squared_error: 19946.2227 - learning_rate: 0.0010
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 19743.4336 - mean_squared_error: 19743.4336 - learning_rate: 0.0010
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 19534.2871 - mean_squared_error: 19534.2871 - learning_rate: 0.0010
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 19318.6133 - mean_squared_error: 19318.6133 - learning_rate: 0.0010
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 19096.2637 - mean_squared_error: 19096.2637 - learning_rate: 0.0010
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 18867.1406 - mean_squared_error: 18867.1406 - learning_rate: 0.0010
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 18631.1738 - mean_squared_error: 18631.1738 - learning_rate: 0.0010
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 18388.3340 - mean_squared_error: 18388.3340 - learning_rate: 0.0010
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 18138.6484 - mean_squared_error: 18138.6484 - learning_rate: 0.0010
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 17882.1758 - mean_squared_error: 17882.1758 - learning_rate: 0.0010
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 17619.0273 - mean_squared_error: 17619.0273 - learning_rate: 0.0010
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 17349.3652 - mean_squared_error: 17349.3652 - learning_rate: 0.0010
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 17073.3848 - mean_squared_error: 17073.3848 - learning_rate: 0.0010
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 16791.3320 - mean_squared_error: 16791.3320 - learning_rate: 0.0010
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 16503.4805 - mean_squared_error: 16503.4805 - learning_rate: 0.0010
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 16210.1309 - mean_squared_error: 16210.1309 - learning_rate: 0.0010
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 15911.6143 - mean_squared_error: 15911.6143 - learning_rate: 0.0010
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - loss: 15608.2656 - mean_squared_error: 15608.2656 - learning_rate: 0.0010
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 15300.4453 - mean_squared_error: 15300.4453 - learning_rate: 0.0010
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 14988.5205 - mean_squared_error: 14988.5205 - learning_rate: 0.0010
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 14672.8701 - mean_squared_error: 14672.8701 - learning_rate: 0.0010
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - loss: 14353.8535 - mean_squared_error: 14353.8535 - learning_rate: 0.0010
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 14031.7988 - mean_squared_error: 14031.7988 - learning_rate: 0.0010
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 13706.9873 - mean_squared_error: 13706.9873 - learning_rate: 0.0010
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 13379.6250 - mean_squared_error: 13379.6250 - learning_rate: 0.0010
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 13049.8604 - mean_squared_error: 13049.8604 - learning_rate: 0.0010
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 12717.7500 - mean_squared_error: 12717.7500 - learning_rate: 0.0010
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 12383.3066 - mean_squared_error: 12383.3066 - learning_rate: 0.0010
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 12046.5146 - mean_squared_error: 12046.5146 - learning_rate: 0.0010
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 11707.3584 - mean_squared_error: 11707.3584 - learning_rate: 0.0010
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 11365.8262 - mean_squared_error: 11365.8262 - learning_rate: 0.0010
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 11021.9004 - mean_squared_error: 11021.9004 - learning_rate: 0.0010
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 10675.5459 - mean_squared_error: 10675.5459 - learning_rate: 0.0010
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 10326.7373 - mean_squared_error: 10326.7373 - learning_rate: 0.0010
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 9975.4727 - mean_squared_error: 9975.4727 - learning_rate: 0.0010
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 9621.7871 - mean_squared_error: 9621.7871 - learning_rate: 0.0010
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 9265.8008 - mean_squared_error: 9265.8008 - learning_rate: 0.0010
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 8907.6914 - mean_squared_error: 8907.6914 - learning_rate: 0.0010
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 8547.7002 - mean_squared_error: 8547.7002 - learning_rate: 0.0010
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 8186.0913 - mean_squared_error: 8186.0913 - learning_rate: 0.0010
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 7823.0928 - mean_squared_error: 7823.0928 - learning_rate: 0.0010
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 7458.9385 - mean_squared_error: 7458.9385 - learning_rate: 0.0010
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 7094.0781 - mean_squared_error: 7094.0781 - learning_rate: 0.0010
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 6729.3584 - mean_squared_error: 6729.3584 - learning_rate: 0.0010
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 6365.9775 - mean_squared_error: 6365.9775 - learning_rate: 0.0010
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 6005.4106 - mean_squared_error: 6005.4106 - learning_rate: 0.0010
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 5649.5327 - mean_squared_error: 5649.5327 - learning_rate: 0.0010
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 5300.6680 - mean_squared_error: 5300.6680 - learning_rate: 0.0010
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 4960.6992 - mean_squared_error: 4960.6992 - learning_rate: 0.0010
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 4629.0244 - mean_squared_error: 4629.0244 - learning_rate: 0.0010
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 4302.4795 - mean_squared_error: 4302.4795 - learning_rate: 0.0010
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 3979.4226 - mean_squared_error: 3979.4226 - learning_rate: 0.0010
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 3660.7192 - mean_squared_error: 3660.7192 - learning_rate: 0.0010
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 3350.3750 - mean_squared_error: 3350.3750 - learning_rate: 0.0010
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 3054.4541 - mean_squared_error: 3054.4541 - learning_rate: 0.0010
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 2777.1274 - mean_squared_error: 2777.1274 - learning_rate: 0.0010
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 2518.8130 - mean_squared_error: 2518.8130 - learning_rate: 0.0010
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 2278.5112 - mean_squared_error: 2278.5112 - learning_rate: 0.0010
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 2056.4595 - mean_squared_error: 2056.4595 - learning_rate: 0.0010
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1853.9720 - mean_squared_error: 1853.9720 - learning_rate: 0.0010
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 1672.0541 - mean_squared_error: 1672.0541 - learning_rate: 0.0010
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1509.8596 - mean_squared_error: 1509.8596 - learning_rate: 0.0010
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 1364.3883 - mean_squared_error: 1364.3883 - learning_rate: 0.0010
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1231.6531 - mean_squared_error: 1231.6531 - learning_rate: 0.0010
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 1108.0227 - mean_squared_error: 1108.0227 - learning_rate: 0.0010
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 990.8071 - mean_squared_error: 990.8071 - learning_rate: 0.0010
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 878.3652 - mean_squared_error: 878.3652 - learning_rate: 0.0010
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 770.2466 - mean_squared_error: 770.2466 - learning_rate: 0.0010
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 667.3665 - mean_squared_error: 667.3665 - learning_rate: 0.0010
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 570.7501 - mean_squared_error: 570.7501 - learning_rate: 0.0010
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 479.3613 - mean_squared_error: 479.3613 - learning_rate: 0.0010
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - loss: 395.8557 - mean_squared_error: 395.8557 - learning_rate: 0.0010
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 325.5613 - mean_squared_error: 325.5613 - learning_rate: 0.0010
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 269.0201 - mean_squared_error: 269.0201 - learning_rate: 0.0010
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 222.3599 - mean_squared_error: 222.3599 - learning_rate: 0.0010
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 182.7559 - mean_squared_error: 182.7559 - learning_rate: 0.0010
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 148.6870 - mean_squared_error: 148.6870 - learning_rate: 0.0010
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 118.3778 - mean_squared_error: 118.3778 - learning_rate: 0.0010
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 91.0832 - mean_squared_error: 91.0832 - learning_rate: 0.0010
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 68.0360 - mean_squared_error: 68.0360 - learning_rate: 0.0010
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 50.5433 - mean_squared_error: 50.5433 - learning_rate: 0.0010
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 37.8786 - mean_squared_error: 37.8786 - learning_rate: 0.0010
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 28.2688 - mean_squared_error: 28.2688 - learning_rate: 0.0010
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 20.9766 - mean_squared_error: 20.9766 - learning_rate: 0.0010
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 15.7690 - mean_squared_error: 15.7690 - learning_rate: 0.0010
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 11.5101 - mean_squared_error: 11.5101 - learning_rate: 0.0010
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 7.2244 - mean_squared_error: 7.2244 - learning_rate: 0.0010
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 3.6187 - mean_squared_error: 3.6187 - learning_rate: 0.0010
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.9204 - mean_squared_error: 1.9204 - learning_rate: 0.0010
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 2.0569 - mean_squared_error: 2.0569 - learning_rate: 0.0010
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 2.9963 - mean_squared_error: 2.9963 - learning_rate: 0.0010
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 3.9880 - mean_squared_error: 3.9880 - learning_rate: 0.0010
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 4.7413 - mean_squared_error: 4.7413 - learning_rate: 0.0010
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 5.0115 - mean_squared_error: 5.0115 - learning_rate: 0.0010
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 4.7227 - mean_squared_error: 4.7227 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 4.4292 - mean_squared_error: 4.4292 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 4.1184 - mean_squared_error: 4.1184 - learning_rate: 5.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.8970 - mean_squared_error: 3.8970 - learning_rate: 5.0000e-04
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.7473 - mean_squared_error: 3.7473 - learning_rate: 5.0000e-04

# %%
# New input data (the last n_steps numbers)
x_input = np.array([55, 89, 144, 233, 377])

# Reshape the input for the model: (1 sample, n_steps timesteps, 1 feature)
x_input = x_input.reshape((1, n_steps, n_features))

# Make the prediction
yhat = gru.predict(x_input)

print(f"\n--- Prediction Result ---")
print(f"Input Sequence: {x_input.flatten()}")
# Round the prediction as Fibonacci numbers are integers
print(f"Predicted Next Number: {round(yhat[0][0])}")
print(f"Expected Next Number: ", x_input.flatten()[-1] + x_input.flatten()[-2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
#
# --- Prediction Result ---
# Input Sequence: [ 55  89 144 233 377]
# Predicted Next Number: 395
# Expected Next Number:  610
