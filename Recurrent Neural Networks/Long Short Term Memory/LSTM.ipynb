# %% [markdown]
# # LSTM (Long Short Term Memory)

# %%
import numpy as np
from keras.callbacks import (
    CSVLogger,
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)
from keras.layers import LSTM, Dense, Input
from keras.losses import MeanSquaredError
from keras.metrics import MeanSquaredError as MSEMetric
from keras.models import Sequential
from keras.optimizers import Adam

# %%
# The Fibonacci Sequence
def fibonacci(n):
    """Generate Fibonacci sequence up to n terms."""
    fib_list = [0, 1]
    for i in range(2, n):
        fib_list.append(fib_list[-1] + fib_list[-2])
    return fib_list[:n]


raw_seq = fibonacci(15)
n_steps = 5  # Use 5 previous numbers to predict the next
n_features = 1


# Function to convert a sequence into (X, y) samples
def create_sequences(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


X, y = create_sequences(raw_seq, n_steps)

# Reshape input to be [samples, timesteps, features] for LSTM
X = X.reshape((X.shape[0], X.shape[1], n_features))

print(f"Sample X (Input): {X[0].flatten()} -> y (Output): {y[0]}")
print(f"Sample X (Input): {X[-1].flatten()} -> y (Output): {y[-1]}")
# Out:
# Sample X (Input): [0 1 1 2 3] -> y (Output): 5
# Sample X (Input): [ 34  55  89 144 233] -> y (Output): 377

# %%
lstm = Sequential(
    layers=[
        Input(shape=(n_steps, n_features)),
        LSTM(64),
        Dense(64),
        Dense(32),
        Dense(1),
    ],
    name="lstm",
)

# %%
lstm.layers
# Out:
# [<LSTM name=lstm, built=True>,
#  <Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %%
lstm.summary()
# Out:
# Model: "lstm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,169 (90.50 KB)
#  Trainable params: 23,169 (90.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm.compile(optimizer=Adam(), loss=MeanSquaredError(), metrics=[MSEMetric()])  # type: ignore

# %%
early_stopping_callback = EarlyStopping(
    monitor="loss", patience=10, restore_best_weights=True
)
model_checkpoint_callback = ModelCheckpoint(
    filepath="../../Models/lstm.keras",
    monitor="loss",
    save_best_only=True,
    mode="min",
)
tensorboard_callback = TensorBoard(
    log_dir="../../Logs/lstm_logs",
    histogram_freq=1,
    write_images=True,
    write_steps_per_second=True,
)
# tensorboard --logdir="Logs/lstm_logs"

csvlogger_callback = CSVLogger("../../Logs/lstm_logs.csv")

reduce_lr_callback = ReduceLROnPlateau(monitor="loss", factor=0.5, patience=5)

lstm_history = lstm.fit(
    X,
    y,
    epochs=200,
    callbacks=[
        early_stopping_callback,
        model_checkpoint_callback,
        tensorboard_callback,
        csvlogger_callback,
        reduce_lr_callback,
    ],
)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 23028.6348 - mean_squared_error: 23028.6348 - learning_rate: 0.0010
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 22934.3770 - mean_squared_error: 22934.3770 - learning_rate: 0.0010
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 22842.6484 - mean_squared_error: 22842.6484 - learning_rate: 0.0010
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 22752.1523 - mean_squared_error: 22752.1523 - learning_rate: 0.0010
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 22662.0723 - mean_squared_error: 22662.0723 - learning_rate: 0.0010
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 22571.8086 - mean_squared_error: 22571.8086 - learning_rate: 0.0010
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 22480.9238 - mean_squared_error: 22480.9238 - learning_rate: 0.0010
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 22389.0410 - mean_squared_error: 22389.0410 - learning_rate: 0.0010
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 22295.7754 - mean_squared_error: 22295.7754 - learning_rate: 0.0010
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 22200.5840 - mean_squared_error: 22200.5840 - learning_rate: 0.0010
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 22102.7227 - mean_squared_error: 22102.7227 - learning_rate: 0.0010
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 22001.4648 - mean_squared_error: 22001.4648 - learning_rate: 0.0010
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 21896.3945 - mean_squared_error: 21896.3945 - learning_rate: 0.0010
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 21787.6152 - mean_squared_error: 21787.6152 - learning_rate: 0.0010
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 21675.4336 - mean_squared_error: 21675.4336 - learning_rate: 0.0010
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 21559.6816 - mean_squared_error: 21559.6816 - learning_rate: 0.0010
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 21439.6523 - mean_squared_error: 21439.6523 - learning_rate: 0.0010
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 21314.5117 - mean_squared_error: 21314.5117 - learning_rate: 0.0010
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 21183.5840 - mean_squared_error: 21183.5840 - learning_rate: 0.0010
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 21046.3770 - mean_squared_error: 21046.3770 - learning_rate: 0.0010
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 20902.5293 - mean_squared_error: 20902.5293 - learning_rate: 0.0010
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 20751.8105 - mean_squared_error: 20751.8105 - learning_rate: 0.0010
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 20594.0488 - mean_squared_error: 20594.0488 - learning_rate: 0.0010
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 20429.1348 - mean_squared_error: 20429.1348 - learning_rate: 0.0010
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 20256.9473 - mean_squared_error: 20256.9473 - learning_rate: 0.0010
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 20077.3145 - mean_squared_error: 20077.3145 - learning_rate: 0.0010
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 19890.0430 - mean_squared_error: 19890.0430 - learning_rate: 0.0010
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 19694.9434 - mean_squared_error: 19694.9434 - learning_rate: 0.0010
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 19491.9023 - mean_squared_error: 19491.9023 - learning_rate: 0.0010
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 19280.8828 - mean_squared_error: 19280.8828 - learning_rate: 0.0010
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 19061.8887 - mean_squared_error: 19061.8887 - learning_rate: 0.0010
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 18834.9277 - mean_squared_error: 18834.9277 - learning_rate: 0.0010
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 18600.0742 - mean_squared_error: 18600.0742 - learning_rate: 0.0010
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 18357.6074 - mean_squared_error: 18357.6074 - learning_rate: 0.0010
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 18108.1191 - mean_squared_error: 18108.1191 - learning_rate: 0.0010
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 17852.2676 - mean_squared_error: 17852.2676 - learning_rate: 0.0010
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 17590.2559 - mean_squared_error: 17590.2559 - learning_rate: 0.0010
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 17321.4258 - mean_squared_error: 17321.4258 - learning_rate: 0.0010
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 17044.4648 - mean_squared_error: 17044.4648 - learning_rate: 0.0010
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 16757.9023 - mean_squared_error: 16757.9023 - learning_rate: 0.0010
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 16460.4277 - mean_squared_error: 16460.4277 - learning_rate: 0.0010
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 16151.0020 - mean_squared_error: 16151.0020 - learning_rate: 0.0010
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 15828.7188 - mean_squared_error: 15828.7188 - learning_rate: 0.0010
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 15492.7168 - mean_squared_error: 15492.7168 - learning_rate: 0.0010
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 15142.2578 - mean_squared_error: 15142.2578 - learning_rate: 0.0010
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 14777.1123 - mean_squared_error: 14777.1123 - learning_rate: 0.0010
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 14397.7109 - mean_squared_error: 14397.7109 - learning_rate: 0.0010
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 14004.8643 - mean_squared_error: 14004.8643 - learning_rate: 0.0010
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 13599.2842 - mean_squared_error: 13599.2842 - learning_rate: 0.0010
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 13181.4062 - mean_squared_error: 13181.4062 - learning_rate: 0.0010
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - loss: 12751.7715 - mean_squared_error: 12751.7715 - learning_rate: 0.0010
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 12311.7422 - mean_squared_error: 12311.7422 - learning_rate: 0.0010
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 11863.7812 - mean_squared_error: 11863.7812 - learning_rate: 0.0010
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 11411.0391 - mean_squared_error: 11411.0391 - learning_rate: 0.0010
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 10956.7871 - mean_squared_error: 10956.7871 - learning_rate: 0.0010
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 10504.6309 - mean_squared_error: 10504.6309 - learning_rate: 0.0010
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - loss: 10058.7578 - mean_squared_error: 10058.7578 - learning_rate: 0.0010
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 9623.6250 - mean_squared_error: 9623.6250 - learning_rate: 0.0010
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 9200.9443 - mean_squared_error: 9200.9443 - learning_rate: 0.0010
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 8781.5811 - mean_squared_error: 8781.5811 - learning_rate: 0.0010
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - loss: 8361.4473 - mean_squared_error: 8361.4473 - learning_rate: 0.0010
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - loss: 7942.1133 - mean_squared_error: 7942.1133 - learning_rate: 0.0010
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 7526.0601 - mean_squared_error: 7526.0601 - learning_rate: 0.0010
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 7116.4009 - mean_squared_error: 7116.4009 - learning_rate: 0.0010
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 6717.1304 - mean_squared_error: 6717.1304 - learning_rate: 0.0010
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 6330.1416 - mean_squared_error: 6330.1416 - learning_rate: 0.0010
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 5947.5210 - mean_squared_error: 5947.5210 - learning_rate: 0.0010
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 5563.4175 - mean_squared_error: 5563.4175 - learning_rate: 0.0010
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 5184.0244 - mean_squared_error: 5184.0244 - learning_rate: 0.0010
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 4815.1514 - mean_squared_error: 4815.1514 - learning_rate: 0.0010
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 4462.1587 - mean_squared_error: 4462.1587 - learning_rate: 0.0010
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 4126.2612 - mean_squared_error: 4126.2612 - learning_rate: 0.0010
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 3804.3523 - mean_squared_error: 3804.3523 - learning_rate: 0.0010
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 3496.3098 - mean_squared_error: 3496.3098 - learning_rate: 0.0010
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 3203.9194 - mean_squared_error: 3203.9194 - learning_rate: 0.0010
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 2927.6599 - mean_squared_error: 2927.6599 - learning_rate: 0.0010
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 2669.2383 - mean_squared_error: 2669.2383 - learning_rate: 0.0010
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 2429.0618 - mean_squared_error: 2429.0618 - learning_rate: 0.0010
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 2204.0378 - mean_squared_error: 2204.0378 - learning_rate: 0.0010
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 1992.2155 - mean_squared_error: 1992.2155 - learning_rate: 0.0010
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 1794.2533 - mean_squared_error: 1794.2533 - learning_rate: 0.0010
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step - loss: 1611.6921 - mean_squared_error: 1611.6921 - learning_rate: 0.0010
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 1443.6157 - mean_squared_error: 1443.6157 - learning_rate: 0.0010
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1287.8320 - mean_squared_error: 1287.8320 - learning_rate: 0.0010
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 1144.7405 - mean_squared_error: 1144.7405 - learning_rate: 0.0010
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 1015.4669 - mean_squared_error: 1015.4669 - learning_rate: 0.0010
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step - loss: 895.1873 - mean_squared_error: 895.1873 - learning_rate: 0.0010
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 783.8265 - mean_squared_error: 783.8265 - learning_rate: 0.0010
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 682.8689 - mean_squared_error: 682.8689 - learning_rate: 0.0010
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 587.3036 - mean_squared_error: 587.3036 - learning_rate: 0.0010
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 498.9884 - mean_squared_error: 498.9884 - learning_rate: 0.0010
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 418.0216 - mean_squared_error: 418.0216 - learning_rate: 0.0010
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 342.6495 - mean_squared_error: 342.6495 - learning_rate: 0.0010
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 277.2930 - mean_squared_error: 277.2930 - learning_rate: 0.0010
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 219.8253 - mean_squared_error: 219.8253 - learning_rate: 0.0010
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 172.9206 - mean_squared_error: 172.9206 - learning_rate: 0.0010
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 133.3316 - mean_squared_error: 133.3316 - learning_rate: 0.0010
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 101.6176 - mean_squared_error: 101.6176 - learning_rate: 0.0010
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 75.5559 - mean_squared_error: 75.5559 - learning_rate: 0.0010
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 54.6094 - mean_squared_error: 54.6094 - learning_rate: 0.0010
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 37.3022 - mean_squared_error: 37.3022 - learning_rate: 0.0010
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 23.7675 - mean_squared_error: 23.7675 - learning_rate: 0.0010
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 13.3651 - mean_squared_error: 13.3651 - learning_rate: 0.0010
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 6.6707 - mean_squared_error: 6.6707 - learning_rate: 0.0010
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 2.7460 - mean_squared_error: 2.7460 - learning_rate: 0.0010
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 1.3803 - mean_squared_error: 1.3803 - learning_rate: 0.0010
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 1.7714 - mean_squared_error: 1.7714 - learning_rate: 0.0010
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 3.0746 - mean_squared_error: 3.0746 - learning_rate: 0.0010
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 4.7424 - mean_squared_error: 4.7424 - learning_rate: 0.0010
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 6.4987 - mean_squared_error: 6.4987 - learning_rate: 0.0010
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 8.5347 - mean_squared_error: 8.5347 - learning_rate: 0.0010
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 10.3090 - mean_squared_error: 10.3090 - learning_rate: 5.0000e-04
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 10.9182 - mean_squared_error: 10.9182 - learning_rate: 5.0000e-04
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step - loss: 10.7716 - mean_squared_error: 10.7716 - learning_rate: 5.0000e-04
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - loss: 9.6670 - mean_squared_error: 9.6670 - learning_rate: 5.0000e-04
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 7.1062 - mean_squared_error: 7.1062 - learning_rate: 5.0000e-04

# %%
# New input data (the last n_steps numbers)
x_input = np.array([55, 89, 144, 233, 377])

# Reshape the input for the model: (1 sample, n_steps timesteps, 1 feature)
x_input = x_input.reshape((1, n_steps, n_features))

# Make the prediction
yhat = lstm.predict(x_input)

print(f"\n--- Prediction Result ---")
print(f"Input Sequence: {x_input.flatten()}")
# Round the prediction as Fibonacci numbers are integers
print(f"Predicted Next Number: {round(yhat[0][0])}")
print(f"Expected Next Number: ", x_input.flatten()[-1] + x_input.flatten()[-2])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
#
# --- Prediction Result ---
# Input Sequence: [ 55  89 144 233 377]
# Predicted Next Number: 381
# Expected Next Number:  610
